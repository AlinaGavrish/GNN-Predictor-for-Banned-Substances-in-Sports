# %%
import pandas as pd
full_dataset = 'try_all.csv'
df = pd.read_csv(full_dataset)
print(df.head()) 
df.shape
# Out:
#   DrugBank ID          Name   CAS Number                Drug Groups  \
# 0     DB00006   Bivalirudin  128270-60-0  approved; investigational
# 1     DB00007    Leuprolide   53714-56-0  approved; investigational
# 2     DB00014     Goserelin   65807-02-5                   approved
# 3     DB00027  Gramicidin D    1405-97-6                   approved
# 4     DB00035  Desmopressin   16679-58-6                   approved
#
#                       InChIKey  \
# 0  OIRCOABEOLEUMC-GEJPAHFPSA-N
# 1  GFIJNRVAKGFPGQ-LIJARHBVSA-N
# 2  BLCLNMBMMGCOAS-URPVMXJPSA-N
# 3  NDAYQJDHGXTBJL-MWWSRJDJSA-N
# 4  NFLWUMRGJYTJIN-PNIOQBSNSA-N
#
#                                                InChI  \
# 0  InChI=1S/C98H138N24O33/c1-5-52(4)82(96(153)122...
# 1  InChI=1S/C59H84N16O12/c1-6-63-57(86)48-14-10-2...
# 2  InChI=1S/C59H84N18O14/c1-31(2)22-40(49(82)68-3...
# 3  InChI=1S/C96H135N19O16/c1-50(2)36-71(105-79(11...
# 4  InChI=1S/C46H64N14O12S2/c47-35(62)15-14-29-40(...
#
#                                               SMILES         Formula  \
# 0  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@...   C98H138N24O33
# 1  CCNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=N)NC(=...    C59H84N16O12
# 2  CC(C)C[C@H](NC(=O)[C@@H](COC(C)(C)C)NC(=O)[C@H...    C59H84N18O14
# 3  CC(C)C[C@@H](NC(=O)CNC(=O)[C@@H](NC=O)C(C)C)C(...   C96H135N19O16
# 4  NC(=O)CC[C@@H]1NC(=O)[C@H](CC2=CC=CC=C2)NC(=O)...  C46H64N14O12S2
#
#   KEGG Compound ID KEGG Drug ID  PubChem Compound ID  PubChem Substance ID  \
# 0              NaN       D03136           16129704.0            46507415.0
# 1           C07612       D08113                  NaN            46507635.0
# 2              NaN       D00573            5311128.0            46507336.0
# 3              NaN       D04369           45267103.0            46507412.0
# 4           C06944       D00291                  NaN                   NaN
#
#    ChEBI ID      ChEMBL ID HET ID  ChemSpider ID  BindingDB ID
# 0   59173.0  CHEMBL2103749    NaN     10482069.0    50248103.0
# 1    6427.0  CHEMBL1201199    NaN       571356.0    50369395.0
# 2    5523.0  CHEMBL1201247    NaN      4470656.0           NaN
# 3       NaN   CHEMBL557217    NaN     24623445.0           NaN
# 4    4450.0     CHEMBL1429    NaN      4470602.0    50205308.0
# (12699, 17)

# %%
def find_strings_in_dataset(string_list, dataset):
    result = {}
    index_set = set()
    for string in string_list:
        words = string.lower().split()
        found = dataset[dataset.apply(lambda row: any(str(word.lower()) in ' '.join(map(str, row.values)).lower() for word in words), axis=1)].index.tolist()
        if found:
            result[string] = found
            index_set.update(found)
        else:
            result[string] = None
    index_list = list(index_set)
    wada_df = dataset.loc[index_list]
    return result, wada_df

# Example list of strings to search for
aas_doped = [
    "Androstenediol",
    ## "1 - Androstenediol"
    "1-Androstenedione",
    ## "1 - Androsterone"
    "Androsterone",
    "Epiandrosterone",
    ## "1-Epiandrosterone",
    "1-Testosterone",
    "4-Androstenediol",
    "4-Hydroxytestosterone",
    "5-Androstenedione",
    "7ɑ-Hydroxy-DHEA",
    "7ß-Hydroxy-DHEA",
    "7-Keto-DHEA",
    "11ß-Methyl-19-nortestosterone",
    "17ɑ-Methylepithiostanol (epistane)",
    "19-Norandrostenediol",
    "19-Norandrostenedione",
    "Androst-4-ene-3,11,17-trione (11-ketoandrostenedione, adrenosterone)",
    "Androstanolone (5ɑ-dihydrotestosterone, 17ß-hydroxy-5ɑ-androstan-3-one)",
    "Androstenediol",
    "Androstenedione",
    "Bolasterone",
    "Boldenone",
    "Boldione",
    "Calusterone",
    "Clostebol",
    "Danazol",
    "Dehydrochlormethyltestosterone",
    "Desoxymethyltestosterone",
    "Dimethandrolone",
    "Drostanolone",
    "Epiandrosterone",
    "Epi-dihydrotestosterone",
    "Epitestosterone",
    "Ethylestrenol",
    "Fluoxymesterone",
    "Formebolone",
    "Furazabol",
    "Gestrinone",
    "Mestanolone",
    "Mesterolone",
    "Metandienone",
    "Metenolone",
    "Methandriol",
    "Methasterone",
    "Methyl-1-testosterone",
    "Methylclostebol",
    "Methyldienolone",
    "Methylnortestosterone",
    "Methyltestosterone",
    "Metribolone",
    "Mibolerone",
    "Nandrolone",
    "Norboletone",
    "Norclostebol",
    "Norethandrolone",
    "Oxabolone",
    "Oxandrolone",
    "Oxymesterone",
    "Oxymetholone",
    "Prasterone",
    "Prostanozol",
    "Quinbolone",
    "Stanozolol",
    "Stenbolone",
    "Testosterone",
    "Tetrahydrogestrinone",
    "Tibolone",
    "Trenbolone",
    "Trestolone"
]

anabolic_other_doped = [
    "Clenbuterol",
    "Osilodrostat",
    "Ractopamine",
    "Andarine",
    "Enobosarm (ostarine)",
    "LGD-4033 (ligandrol)",
    "RAD140",
    "S-23",
    "YK-11",
    "Zeranol",
    "Zilpaterol"
]

peptide_growth_mimetic_doped = [
    "EPO-Fc",
    "polyethylene glycol", # "methoxy polyethylene glycol-epoetin beta"
    "CNTO-530",
    "peginesatide",
    "cobalt",
    "daprodustat (GSK1278863)",
    "IOX2",
    "molidustat (BAY 85-3934)",
    "roxadustat (FG-4592)",
    "vadadustat (AKB-6548)",
    "xenon", 
    "K-11706",
    "luspatercept", 
    "sotatercept", 
    "asialo", # "asialo EPO"
    "carbamylated EPO (CEPO)", 
    "buserelin",
    "deslorelin", 
    "goserelin",
    "histrelin", 
    "leuprorelin", 
    "nafarelin", 
    "triptorelin",
    "gonadorelin",
    "kisspeptin",
    "corticorelin",
    "tetracosactide",
    "lonapegsomatropin",
    "somapacitan",
    "somatrogon",
    "AOD-9604",
    "hGH 176-191",
    "CJC-1293",
    "CJC-1295",
    "sermorelin",
    "tesamorelin",
    "anamorelin",
    "capromorelin",
    "ibutamoren (MK-677)",
    "ipamorelin",
    "lenomorelin (ghrelin)",
    "macimorelin", 
    "tabimorelin",
    "alexamorelin",
    "examorelin (hexarelin)",
    "GHRP-1",
    "GHRP-2 (pralmorelin)",
    "GHRP-3", 
    "GHRP-4",
    "GHRP-5", 
    "GHRP-6"
]

beta_2_doped = [
    "Arformoterol",
    "Fenoterol",
    "Formoterol",
    "Higenamine",
    "Indacaterol",
    "Levosalbutamol",
    "Olodaterol",
    "Procaterol", 
    "Reproterol",
    "Salbutamol",
    "Salmeterol",
    "Terbutaline",
    "Tretoquinol (trimetoquinol)",
    "Tulobuterol",
    "Vilanterol"
]

hormone_metabolic_modulators_doped = [
    "2-Androstenol (5ɑ-androst-2-en-17-ol)",
    "2-Androstenone (5ɑ-androst-2-en-17-one)",
    "3-Androstenol (5ɑ-androst-3-en-17-ol)", 
    "3-Androstenone (5ɑ-androst-3-en-17-one)",
    "4-Androstene-3,6,17 trione (6-oxo)",
    "Aminoglutethimide",
    "Anastrozole",
    "androstatrienedione",
    "arimistane",
    "Exemestane",
    "Formestane",
    "Letrozole",
    "Testolactone",
    "Bazedoxifene",
    "Clomifene",
    "Cyclofenil",
    "Fulvestrant",
    "Ospemifene",
    "Raloxifene",
    "Tamoxifen",
    "Toremifene",
    "ACE-031",
    "bimagrumab",
    "follistatin",
    "myostatin",
    "propeptide",
    "apitegromab", 
    "domagrozumab",
    "landogrozumab",
    "stamulumab",
    "AICAR",
    "GW1516",
    "GW501516",
    "SR9009",
    "SR9011",
    "Meldonium",
    "Trimetazidine"
]

diuretics_doped = [
    "Acetazolamide",
    "amiloride",
    "bumetanide",
    "canrenone",
    "chlortalidone",
    "etacrynic", # "etacrynic acid - had to remove acid"
    "furosemide",
    "indapamide",
    "metolazone",
    "spironolactone",
    "thiazides",
    "bendroflumethiazide",
    "chlorothiazide",
    "hydrochlorothiazide",
    "torasemide",
    "triamterene",
    "vaptan",
    "conivaptan",
    "mozavaptan",
    "tolvaptan",
    "Albumin",
    "dextran",
    "hydroxyethylstarch",
    "mannitol",
    "Desmopressin",
    "Probenecid"
]

stimulants_doped = [
    "Adrafinil",
    "Amfepramone",
    "Amfetamine",
    "Amfetaminil",
    "Amiphenazole",
    "Benfluorex",
    "Benzylpiperazine",
    "Bromantan",
    "Clobenzorex",
    "Cocaine",
    "Cropropamide",
    "Crotetamide",
    "Fencamine",
    "Fenetylline",
    "Fenfluramine",
    "Fenproporex",
    "Fonturacetam [4-phenylpiracetam (carphedon)]",
    "Furfenorex",
    "Lisdexamfetamine",
    "Mefenorex",
    "Mephentermine",
    "Mesocarb",
    "Metamfetamine(d-)",
    "p-methylamfetamine",
    "Modafinil",
    "Norfenfluramine",
    "Phendimetrazine",
    "Phentermine",
    "Prenylamine",
    "Prolintane",
    "2-phenylpropan-1-amine (ß-methylphenylethylamine, BMPEA)",
    "3-Methylhexan-2-amine (1,2-dimethylpentylamine)",
    "4-Fluoromethylphenidate",
    "methylhexaneamine",
    "4-Methylpentan-2-amine (1,3-dimethylbutylamine)",
    "5-Methylhexan-2-amine (1,4-dimethylamylamine, 1,4-dimethylpentylamine, 1,4-DMAA)",
    "Benzfetamine",
    "Cathine",
    "Cathinone",
    "mephedrone",
    "methedrone",
    "ɑ-pyrrolidinovalerophenone",
    "Dimetamfetamine (dimethylamphetamine)",
    "Ephedrine",
    "Epinephrine (adrenaline)",
    "Etamivan",
    "Ethylphenidate",
    "Etilamfetamine",
    "Etilefrine",
    "Famprofazone",
    "Fenbutrazate",
    "Fencamfamin",
    "Heptaminol",
    "Hydrafinil (fluorenol)",
    "Hydroxyamfetamine (parahydroxyamphetamine)",
    "Isometheptene",
    "Levmetamfetamine",
    "Meclofenoxate",
    "Methylenedioxymethamphetamine",
    "Methylephedrine",
    "Methylnaphthidate [(±)-methyl-2-(naphthalen-2-yl)-2-(piperidin-2-yl)acetate]",
    "Methylphenidate",
    "Nikethamide",
    "Norfenefrine",
    "Octodrine (1,5-dimethylhexylamine)",
    "Octopamine",
    "Oxilofrine (methylsynephrine)",
    "Pemoline",
    "Pentetrazol",
    "Phenethylamine",
    "Phenmetrazine",
    "Phenpromethamine",
    "Propylhexedrine",
    "Pseudoephedrine",
    "Selegiline",
    "Sibutramine",
    "Solriamfetol",
    "Strychnine",
    "Tenamfetamine (methylenedioxyamphetamine)",
    "Tuaminoheptane"
]
narcotics_doped = [
    "Buprenorphine",
    "Dextromoramide",
    "Diamorphine (heroin)",
    "Fentanyl",
    "Hydromorphone",
    "Methadone",
    "Morphine",
    "Nicomorphine",
    "Oxycodone",
    "Oxymorphone",
    "Pentazocine",
    "Pethidine",
    "Tramadol"
]
glucocorticoids_doped = [
    "Beclometasone",
    "Betamethasone",
    "Budesonide",
    "Ciclesonide",
    "Cortisone",
    "Deflazacort",
    "Dexamethasone",
    "Flunisolide",
    "Fluocortolone",
    "Fluticasone",
    "Hydrocortisone",
    "Methylprednisolone",
    "Mometasone",
    "Prednisolone",
    "Prednisone",
    "Triamcinolone acetonide"
]

beta_blockers_doped = [
    "Acebutolol",
    "Alprenolol",
    "Atenolol",
    "Betaxolol",
    "Bisoprolol",
    "Bunolol",
    "Carteolol",
    "Carvedilol",
    "Celiprolol",
    "Esmolol",
    "Labetalol",
    "Metipranolol",
    "Metoprolol",
    "Nadolol",
    "Nebivolol",
    "Oxprenolol",
    "Pindolol",
    "Propranolol",
    "Sotalol",
    "Timolol"
]

all_strings = aas_doped + anabolic_other_doped + peptide_growth_mimetic_doped + beta_2_doped + hormone_metabolic_modulators_doped + diuretics_doped + stimulants_doped + narcotics_doped + glucocorticoids_doped + beta_blockers_doped
output, wada_df = find_strings_in_dataset(all_strings, df)
for key, value in output.items():
    print(f"{key}: {value}")
wada_df.to_csv('wada_list.csv', index=False)
print(wada_df.shape)
# Out:
# Androstenediol: [1278, 1324, 1340, 1342]
# 1-Androstenedione: [1274]
# Androsterone: [4625, 5393]
# Epiandrosterone: [4625, 5393]
# 1-Testosterone: [1303, 1388]
# 4-Androstenediol: [1342]
# 4-Hydroxytestosterone: [1307]
# 5-Androstenedione: [1267, 1279]
# 7ɑ-Hydroxy-DHEA: None
# 7ß-Hydroxy-DHEA: None
# 7-Keto-DHEA: None
# 11ß-Methyl-19-nortestosterone: None
# 17ɑ-Methylepithiostanol (epistane): None
# 19-Norandrostenediol: None
# 19-Norandrostenedione: [1258]
# Androst-4-ene-3,11,17-trione (11-ketoandrostenedione, adrenosterone): None
# Androstanolone (5ɑ-dihydrotestosterone, 17ß-hydroxy-5ɑ-androstan-3-one): None
# Androstenedione: [1258, 1267, 1272, 1274, 1279, 1352]
# Bolasterone: [1293]
# Boldenone: [1357, 10749]
# Boldione: [6087]
# Calusterone: [1380]
# Clostebol: [1337, 11528]
# Danazol: [1231, 10322]
# Dehydrochlormethyltestosterone: None
# Desoxymethyltestosterone: None
# Dimethandrolone: [11657]
# Drostanolone: [744, 10765]
# Epi-dihydrotestosterone: None
# Epitestosterone: [6463]
# Ethylestrenol: [1314, 10034]
# Fluoxymesterone: [1068]
# Formebolone: [1385]
# Furazabol: [1332]
# Gestrinone: [5591, 8414]
# Mestanolone: None
# Mesterolone: [10086]
# Metandienone: [10085]
# Metenolone: [10206]
# Methandriol: None
# Methasterone: None
# Methyl-1-testosterone: [1388]
# Methylclostebol: None
# Methyldienolone: None
# Methylnortestosterone: None
# Methyltestosterone: [1328, 5449]
# Metribolone: [2709]
# Mibolerone: [8280]
# Nandrolone: [870, 1356, 7453, 9702, 10734]
# Norboletone: None
# Norclostebol: None
# Norethandrolone: [9388]
# Oxabolone: [1321, 9715]
# Oxandrolone: [511]
# Oxymesterone: [1068]
# Oxymetholone: [5280]
# Prasterone: [1513, 4996, 11858]
# Prostanozol: None
# Quinbolone: [9988]
# Stanozolol: [5457]
# Stenbolone: None
# Testosterone: [514, 1244, 1303, 1307, 1328, 1359, 1388, 5449, 6156, 6463, 7278, 10400, 10401, 10402, 10403, 10520, 11542, 11543, 11544]
# Tetrahydrogestrinone: [5591]
# Tibolone: [7666]
# Trenbolone: [8371, 10770]
# Trestolone: [5009, 10414]
# Clenbuterol: [1232]
# Osilodrostat: [8598]
# Ractopamine: [8364]
# Andarine: [6134]
# Enobosarm (ostarine): [8801]
# LGD-4033 (ligandrol): None
# RAD140: None
# S-23: [4997, 6130, 12472]
# YK-11: None
# Zeranol: [8323]
# Zilpaterol: [8324]
# EPO-Fc: None
# polyethylene glycol: [1635, 1932, 2088, 2159, 2457, 2736, 2789, 3082, 3189, 3230, 7031, 7860, 8027, 8089, 8122, 8141, 8197, 10535, 10554, 10558, 10727, 11262]
# CNTO-530: None
# peginesatide: None
# cobalt: [3041, 10608, 10609, 10717, 11226, 11405]
# daprodustat (GSK1278863): [8464]
# IOX2: None
# molidustat (BAY 85-3934): [11364]
# roxadustat (FG-4592): [4445]
# vadadustat (AKB-6548): [8949]
# xenon: [7883, 7966, 9958, 12233]
# K-11706: None
# luspatercept: None
# sotatercept: None
# asialo: None
# carbamylated EPO (CEPO): [352, 367, 394, 454, 1123, 1665, 2383, 2639, 3790, 4460, 4488, 4540, 7040, 7059, 7298, 7338, 7357, 8312, 8849, 8957, 9441, 9512, 10297, 10300, 10666, 10690, 10753, 11067, 11924, 12231, 12328, 12617]
# buserelin: [5458]
# deslorelin: [8343]
# goserelin: [2]
# histrelin: [5518]
# leuprorelin: None
# nafarelin: [555]
# triptorelin: [5549]
# gonadorelin: [533]
# kisspeptin: None
# corticorelin: [4800, 9485]
# tetracosactide: [1157]
# lonapegsomatropin: None
# somapacitan: None
# somatrogon: None
# AOD-9604: None
# hGH 176-191: [416, 1846, 3238, 3610, 3865, 3959, 5746, 7095, 10149, 10873, 12158, 12388, 12571]
# CJC-1293: None
# CJC-1295: None
# sermorelin: None
# tesamorelin: None
# anamorelin: [5408]
# capromorelin: [11110]
# ibutamoren (MK-677): [12561]
# ipamorelin: [9042]
# lenomorelin (ghrelin): None
# macimorelin: [9624]
# tabimorelin: None
# alexamorelin: None
# examorelin (hexarelin): None
# GHRP-1: None
# GHRP-2 (pralmorelin): None
# GHRP-3: None
# GHRP-4: None
# GHRP-5: None
# GHRP-6: None
# Arformoterol: [1151]
# Fenoterol: [1158]
# Formoterol: [869, 1151]
# Higenamine: [9381]
# Indacaterol: [4575]
# Levosalbutamol: [9682]
# Olodaterol: [7675]
# Procaterol: [1207]
# Reproterol: [9428]
# Salbutamol: [887, 9682]
# Salmeterol: [824]
# Terbutaline: [757]
# Tretoquinol (trimetoquinol): [10188]
# Tulobuterol: [8944]
# Vilanterol: [7677]
# 2-Androstenol (5ɑ-androst-2-en-17-ol): None
# 2-Androstenone (5ɑ-androst-2-en-17-one): None
# 3-Androstenol (5ɑ-androst-3-en-17-ol): None
# 3-Androstenone (5ɑ-androst-3-en-17-one): None
# 4-Androstene-3,6,17 trione (6-oxo): [3058, 3290, 5836, 7060]
# Aminoglutethimide: [250]
# Anastrozole: [1100]
# androstatrienedione: None
# arimistane: None
# Exemestane: [876]
# Formestane: [7528]
# Letrozole: [892]
# Testolactone: [780]
# Bazedoxifene: [5272]
# Clomifene: [768]
# Cyclofenil: [9976]
# Fulvestrant: [833]
# Ospemifene: [4515]
# Raloxifene: [373]
# Tamoxifen: [563]
# Toremifene: [429]
# ACE-031: None
# bimagrumab: None
# follistatin: None
# myostatin: None
# propeptide: None
# apitegromab: None
# domagrozumab: None
# landogrozumab: None
# stamulumab: None
# AICAR: None
# GW1516: None
# GW501516: None
# SR9009: None
# SR9011: None
# Meldonium: [10219]
# Trimetazidine: [7665]
# Acetazolamide: [705]
# amiloride: [484]
# bumetanide: [773]
# canrenone: [8919]
# chlortalidone: None
# etacrynic: [789]
# furosemide: [583]
# indapamide: [694, 6176]
# metolazone: [414]
# spironolactone: [313]
# thiazides: None
# bendroflumethiazide: [328]
# chlorothiazide: [766, 885]
# hydrochlorothiazide: [885]
# torasemide: [108]
# triamterene: [277]
# vaptan: [758, 5184, 5418, 9269, 10389, 10873, 10933, 11750]
# conivaptan: [758]
# mozavaptan: None
# tolvaptan: [5184]
# Albumin: None
# dextran: [779, 7830, 10060, 12370]
# hydroxyethylstarch: None
# mannitol: [629, 4332, 8818, 11889]
# Desmopressin: [4]
# Probenecid: [917]
# Adrafinil: [7544]
# Amfepramone: None
# Amfetamine: [1138, 1327, 1393, 8010, 9797]
# Amfetaminil: None
# Amiphenazole: None
# Benfluorex: [7636]
# Benzylpiperazine: None
# Bromantan: None
# Clobenzorex: [10061]
# Cocaine: [793]
# Cropropamide: None
# Crotetamide: None
# Fencamine: None
# Fenetylline: None
# Fenfluramine: [464, 1074]
# Fenproporex: [1366]
# Fonturacetam [4-phenylpiracetam (carphedon)]: None
# Furfenorex: None
# Lisdexamfetamine: [1138]
# Mefenorex: [10347]
# Mephentermine: [1206]
# Mesocarb: None
# Metamfetamine(d-): None
# p-methylamfetamine: None
# Modafinil: [632, 5281]
# Norfenfluramine: None
# Phendimetrazine: [1395]
# Phentermine: [85, 1206, 1372]
# Prenylamine: [4423]
# Prolintane: [9945]
# 2-phenylpropan-1-amine (ß-methylphenylethylamine, BMPEA): None
# 3-Methylhexan-2-amine (1,2-dimethylpentylamine): None
# 4-Fluoromethylphenidate: None
# methylhexaneamine: None
# 4-Methylpentan-2-amine (1,3-dimethylbutylamine): None
# 5-Methylhexan-2-amine (1,4-dimethylamylamine, 1,4-dimethylpentylamine, 1,4-DMAA): None
# Benzfetamine: None
# Cathine: [1308]
# Cathinone: [1376, 11201]
# mephedrone: [9656]
# methedrone: None
# ɑ-pyrrolidinovalerophenone: None
# Dimetamfetamine (dimethylamphetamine): None
# Ephedrine: [738, 1205, 8173, 10828, 11531]
# Epinephrine (adrenaline): [261, 556, 8058, 10381]
# Etamivan: [7604]
# Ethylphenidate: [314, 5440, 11861]
# Etilamfetamine: [9797]
# Etilefrine: [7600]
# Famprofazone: [11879]
# Fenbutrazate: None
# Fencamfamin: [1285]
# Heptaminol: [10073]
# Hydrafinil (fluorenol): None
# Hydroxyamfetamine (parahydroxyamphetamine): None
# Isometheptene: [5445, 11653]
# Levmetamfetamine: [8010]
# Meclofenoxate: [10254]
# Methylenedioxymethamphetamine: None
# Methylephedrine: [8173]
# Methylnaphthidate [(±)-methyl-2-(naphthalen-2-yl)-2-(piperidin-2-yl)acetate]: None
# Methylphenidate: [314, 5440, 11861]
# Nikethamide: [10151]
# Norfenefrine: [9887]
# Octodrine (1,5-dimethylhexylamine): None
# Octopamine: [9766]
# Oxilofrine (methylsynephrine): [8407]
# Pemoline: [1113]
# Pentetrazol: [9923]
# Phenethylamine: [1280, 1353, 3953]
# Phenmetrazine: [716]
# Phenpromethamine: None
# Propylhexedrine: [5453]
# Pseudoephedrine: [738]
# Selegiline: [922]
# Sibutramine: [988]
# Solriamfetol: [10830]
# Strychnine: [11500]
# Tenamfetamine (methylenedioxyamphetamine): [1327]
# Tuaminoheptane: [9754]
# Buprenorphine: [807, 11638]
# Dextromoramide: [1345]
# Diamorphine (heroin): [1275]
# Fentanyl: [699, 1263, 1276, 1292, 1348, 1373, 1386, 1387, 7747, 7748, 7749, 7750, 7752, 7755, 7758, 7760]
# Hydromorphone: [221]
# Methadone: [226, 8406, 10018, 11103]
# Morphine: [189, 602, 1275, 1288, 1347, 1381, 1389, 5278, 9959, 12006, 12181]
# Nicomorphine: [9959]
# Oxycodone: [389]
# Oxymorphone: [1075]
# Pentazocine: [541]
# Pethidine: None
# Tramadol: [87]
# Beclometasone: None
# Betamethasone: [335, 10779]
# Budesonide: [1105]
# Ciclesonide: [1235]
# Cortisone: [575, 628, 1215, 10690, 10691, 10692, 10693, 10694, 10695, 10696, 10697, 10791]
# Deflazacort: [8667]
# Dexamethasone: [1117, 8329, 10759, 10798]
# Flunisolide: [74, 10772]
# Fluocortolone: [7587, 7690, 10774, 11412, 11430]
# Fluticasone: [478, 7529, 10360]
# Hydrocortisone: [628, 10690, 10691, 10692, 10693, 10694, 10695, 10696, 10697]
# Methylprednisolone: [845, 10753, 10754]
# Mometasone: [651, 10664]
# Prednisolone: [746, 845, 7930, 10741, 10742, 10743, 10747, 10753, 10754, 11318, 11540]
# Prednisone: [525, 7934, 9515, 10735, 10756, 11514]
# Triamcinolone acetonide: [481, 510, 7589]
# Acebutolol: [1076]
# Alprenolol: [752]
# Atenolol: [228, 5706, 9949]
# Betaxolol: [89, 7912]
# Bisoprolol: [502]
# Bunolol: [1093]
# Carteolol: [411]
# Carvedilol: [1019]
# Celiprolol: [4444]
# Esmolol: [81]
# Labetalol: [488]
# Metipranolol: [1097]
# Metoprolol: [158]
# Nadolol: [1086]
# Nebivolol: [4459]
# Oxprenolol: [1396]
# Pindolol: [846, 7456, 10031]
# Propranolol: [461, 3015]
# Sotalol: [381]
# Timolol: [266]
# (425, 17)

# %%
wada_df = wada_df[['DrugBank ID', 'Name', 'Drug Groups', 'SMILES', 'Formula']]
# List of all drugs under doping according to WADA 2024 list
wada_df['Doping'] = 1

print(wada_df.head(10))

wada_df.to_csv('wada_filtered.csv', index=False)
# Out:
#       DrugBank ID                       Name      Drug Groups  \
# 2         DB00014                  Goserelin         approved
# 4         DB00035               Desmopressin         approved
# 8197      DB11323          Glycol salicylate         approved
# 6156      DB07447  5beta-dihydrotestosterone     experimental
# 10254     DB13758              Meclofenoxate     experimental
# 6176      DB07467             (S)-Indapamide     experimental
# 2088      DB02327         Triethylene glycol     experimental
# 12328     DB17692                 Vamifeport  investigational
# 10297     DB13802                  Epomediol     experimental
# 10300     DB13805                    Reposal     experimental
#
#                                                   SMILES         Formula  \
# 2      CC(C)C[C@H](NC(=O)[C@@H](COC(C)(C)C)NC(=O)[C@H...    C59H84N18O14
# 4      NC(=O)CC[C@@H]1NC(=O)[C@H](CC2=CC=CC=C2)NC(=O)...  C46H64N14O12S2
# 8197                               OCCOC(=O)C1=CC=CC=C1O         C9H10O4
# 6156   [H][C@]1(O)CC[C@@]2([H])[C@]3([H])CC[C@]4([H])...        C19H30O2
# 10254                     CN(C)CCOC(=O)COC1=CC=C(Cl)C=C1     C12H16ClNO3
# 6176   C[C@H]1CC2=C(C=CC=C2)N1NC(=O)C1=CC=C(Cl)C(=C1)...   C16H16ClN3O3S
# 2088                                          OCCOCCOCCO         C6H14O4
# 12328  FC1=CC=CN=C1CNC(=O)C1=COC(CCNCCC2=NC3=CC=CC=C3...     C21H21FN6O2
# 10297          CC1(C)O[C@@]2(C)[C@@H](O)C[C@@H]1C[C@H]2O        C10H18O3
# 10300              CCC1(C(=O)NC(=O)NC1=O)C1=CC2CCC(C2)C1      C14H18N2O3
#
#        Doping
# 2           1
# 4           1
# 8197        1
# 6156        1
# 10254       1
# 6176        1
# 2088        1
# 12328       1
# 10297       1
# 10300       1

# %%
print(df.iloc[1513])
# Out:
# DrugBank ID                                                       DB01708
# Name                                                           Prasterone
# CAS Number                                                        53-43-0
# Drug Groups                      approved; investigational; nutraceutical
# InChIKey                                      FMGSKLZLMKYGDP-USOAJAOKSA-N
# InChI                   InChI=1S/C19H28O2/c1-18-9-7-13(20)11-12(18)3-4...
# SMILES                  [H][C@@]12CCC(=O)[C@@]1(C)CC[C@@]1([H])[C@@]2(...
# Formula                                                          C19H28O2
# KEGG Compound ID                                                   C01227
# KEGG Drug ID                                                       D08409
# PubChem Compound ID                                                5881.0
# PubChem Substance ID                                           46508824.0
# ChEBI ID                                                          28689.0
# ChEMBL ID                                                     CHEMBL90593
# HET ID                                                                AND
# ChemSpider ID                                                      5670.0
# BindingDB ID                                                   50223368.0
# Name: 1513, dtype: object

# %%
print(df.iloc[4996])
# Out:
# DrugBank ID                                                       DB05804
# Name                                                   Prasterone sulfate
# CAS Number                                                       651-48-9
# Drug Groups                                               investigational
# InChIKey                                      CZWCKYRVOZZJNM-USOAJAOKSA-N
# InChI                   InChI=1S/C19H28O5S/c1-18-9-7-13(24-25(21,22)23...
# SMILES                  [H][C@@]12CCC(=O)[C@@]1(C)CC[C@@]1([H])[C@@]2(...
# Formula                                                         C19H28O5S
# KEGG Compound ID                                                   C04555
# KEGG Drug ID                                                          NaN
# PubChem Compound ID                                               12594.0
# PubChem Substance ID                                          175427036.0
# ChEBI ID                                                          16814.0
# ChEMBL ID                                                    CHEMBL259898
# HET ID                                                                ZWY
# ChemSpider ID                                                     12074.0
# BindingDB ID                                                   50375559.0
# Name: 4996, dtype: object

# %%
print(df.iloc[12698])
# Out:
# DrugBank ID                               DB18717
# Name                                     Graphite
# CAS Number                              7782-42-5
# Drug Groups             approved; investigational
# InChIKey                                      NaN
# InChI                                         NaN
# SMILES                                        NaN
# Formula                                       NaN
# KEGG Compound ID                              NaN
# KEGG Drug ID                                  NaN
# PubChem Compound ID                           NaN
# PubChem Substance ID                          NaN
# ChEBI ID                                      NaN
# ChEMBL ID                                     NaN
# HET ID                                        NaN
# ChemSpider ID                                 NaN
# BindingDB ID                                  NaN
# Name: 12698, dtype: object

# %%
#Mix of drugs that include such combinations as "approved, illicit" whcih needs to be tested if they are doping or not

default_doping = ['withdrawn', 'experimental', 'illicit', 'investigational']

filtered_df = df[df['Drug Groups'].str.split('; ').apply(lambda x: any(item in x for item in default_doping))]

print(filtered_df.head())
filtered_df.shape

# %%
# Not doping by default. Drugs have to be manually checked. Can be used as a test_data
filtered_df2 = df[~df['Drug Groups'].str.split('; ').apply(lambda x: any(item in x for item in default_doping))]

print(filtered_df2.head())
print(filtered_df2.shape)

# %%
#This data represents all drugs that are Doping by default according to WADA

not_doped_default = ['approved', 'nutraceutical']

filtered_df3 = df[~df['Drug Groups'].str.split('; ').apply(lambda x: any(item in x for item in not_doped_default))]
filtered_df3 = filtered_df3[['DrugBank ID', 'Name', 'Drug Groups', 'SMILES', 'Formula']]
# all drugs under this category are considered Doping and have value of 1
filtered_df3['Doping'] = 1

print(filtered_df3.head())
print(filtered_df3.shape)

filtered_df3.to_csv('doping_default.csv', index=False)

# %%
smiles_doped = filtered_df3['SMILES'].tolist()
print(smiles_doped)

# %%
# Install required packages.
import os
import torch
os.environ['TORCH'] = torch.__version__
print(torch.__version__)

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git
# !pip install -q captum
# !pip install -q pysmiles

# Helper function for visualization.
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from pysmiles import read_smiles
import networkx as nx

smiles1 = 'C=CCCC(=O)Cl'
smiles2 = 'CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=N)NC(=O)[C@@H]1CCCN1C(=O)[C@H](N)CC1=CC=CC=C1)C(=O)N1CCC[C@H]1C(=O)N[C@@H](CCC(O)=O)C(=O)N[C@@H](CCC(O)=O)C(=O)N[C@@H](CC1=CC=C(O)C=C1)C(=O)N[C@@H](CC(C)C)C(O)=O'
mol = read_smiles(smiles1)
#, explicit_hydrogen=True
# atom vector (C only)
#print(mol.nodes(data='element'))

# adjacency matrix

adj_matrix = nx.adjacency_matrix(mol, weight='order')
adj_matrix_array = adj_matrix.toarray()
print(adj_matrix_array)
#print(nx.to_numpy_matrix(mol, weight='order'))

elements = nx.get_node_attributes(mol, name = "element")
nx.draw(mol, with_labels=True, labels = elements, pos=nx.spring_layout(mol))
plt.gca().set_aspect('equal')

# %%
from pysmiles import read_smiles
import networkx as nx
import matplotlib.pyplot as plt
import logging
logging.getLogger('pysmiles').setLevel(logging.CRITICAL)  # Anything higher than warning


for idx, smiles in enumerate(smiles_doped):
    smiles_str = str(smiles)
    try:
        mol = read_smiles(smiles_str)
        elements = nx.get_node_attributes(mol, name="element")
        filtered_df3 = filtered_df3.reset_index(drop=True)
        drug_name = filtered_df3.loc[idx, 'Name']
        
        print("SMILES #{}: {} - {}".format(idx, drug_name, smiles_str))
    except ValueError as e:
        print("Error processing SMILES #{}: {}".format(idx, e))
        continue

    nx.draw(mol, with_labels=True, labels=elements, pos=nx.spring_layout(mol))
    plt.gca().set_aspect('equal')
    plt.show()

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit import DataStructs
# Create an empty graph
# Convert the 'SMILES' column to string and replace any NaN values with an empty string
filtered_df3['SMILES'] = filtered_df3['SMILES'].astype(str).replace('nan', '')

# Create an empty graph
G = nx.Graph()

# Add nodes for drugs
for idx, row in filtered_df3.iterrows():
    smiles = row['SMILES']
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        G.add_node(row['DrugBank ID'], name=row['Name'], groups=row['Drug Groups'], smiles=smiles, formula=row['Formula'], doping=row['Doping'])

# Calculate Morgan fingerprints for drugs
fingerprints = {}
for idx, row in filtered_df3.iterrows():
    mol = Chem.MolFromSmiles(row['SMILES'])
    if mol:
        fp = AllChem.GetMorganFingerprintAsBitVect(mol, 2)
        fingerprints[row['DrugBank ID']] = fp

# Calculate Tanimoto similarity between drugs
similarities = {}
for drug1_id, fp1 in fingerprints.items():
    for drug2_id, fp2 in fingerprints.items():
        if drug1_id != drug2_id:
            similarity = DataStructs.TanimotoSimilarity(fp1, fp2)
            if similarity > 0.7:  # Adjust threshold as needed
                if (drug2_id, drug1_id) not in similarities:  # Avoid duplicate edges
                    similarities[(drug1_id, drug2_id)] = similarity

# Add edges to the graph based on similarity
for (drug1_id, drug2_id), similarity in similarities.items():
    G.add_edge(drug1_id, drug2_id, similarity=similarity)

# Visualize the graph
pos = nx.spring_layout(G)  # Positions for all nodes
nx.draw(G, pos, with_labels=True, node_size=3000, node_color='skyblue', font_size=10, font_weight='bold')
plt.show()

# %%
# Add nodes for drugs (only the first 10 rows)
for idx, row in filtered_df3.head(10).iterrows():
    smiles = row['SMILES']
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        G.add_node(row['DrugBank ID'], name=row['Name'], groups=row['Drug Groups'], smiles=smiles, formula=row['Formula'], doping=row['Doping'])

# Calculate Morgan fingerprints for drugs (only the first 10 rows)
fingerprints = {}
for idx, row in filtered_df3.head(10).iterrows():
    mol = Chem.MolFromSmiles(row['SMILES'])
    if mol:
        fp = AllChem.GetMorganFingerprintAsBitVect(mol, 2)
        fingerprints[row['DrugBank ID']] = fp

# Calculate Tanimoto similarity between drugs (only the first 10 rows)
similarities = {}
for drug1_id, fp1 in fingerprints.items():
    for drug2_id, fp2 in fingerprints.items():
        if drug1_id != drug2_id:
            similarity = DataStructs.TanimotoSimilarity(fp1, fp2)
            if similarity > 0.7:  # Adjust threshold as needed
                if (drug2_id, drug1_id) not in similarities:  # Avoid duplicate edges
                    similarities[(drug1_id, drug2_id)] = similarity

# Add edges to the graph based on similarity
for (drug1_id, drug2_id), similarity in similarities.items():
    G.add_edge(drug1_id, drug2_id, similarity=similarity)

# Visualize the graph
pos = nx.spring_layout(G)  # Positions for all nodes
nx.draw(G, pos, with_labels=True, node_size=3000, node_color='skyblue', font_size=10, font_weight='bold')
plt.show()

# %%
G = nx.Graph()
# Add nodes for drugs (only the first 10 rows)
for idx, row in filtered_df3.head(50).iterrows():
    smiles = row['SMILES']
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        G.add_node(row['DrugBank ID'], name=row['Name'], groups=row['Drug Groups'], smiles=smiles, formula=row['Formula'], doping=row['Doping'])

# Calculate Morgan fingerprints for drugs (only the first 10 rows)
fingerprints = {}
for idx, row in filtered_df3.head(50).iterrows():
    mol = Chem.MolFromSmiles(row['SMILES'])
    if mol:
        fp = AllChem.GetMorganFingerprintAsBitVect(mol, 2)
        fingerprints[row['DrugBank ID']] = fp

# Calculate Tanimoto similarity between drugs (only the first 10 rows)
similarities = {}
for drug1_id, fp1 in fingerprints.items():
    for drug2_id, fp2 in fingerprints.items():
        if drug1_id != drug2_id:
            similarity = DataStructs.TanimotoSimilarity(fp1, fp2)
            if similarity > 0.7:  # Adjust threshold as needed
                if (drug2_id, drug1_id) not in similarities:  # Avoid duplicate edges
                    similarities[(drug1_id, drug2_id)] = similarity

# Add edges to the graph based on similarity (only for the first 10 drugs)
for (drug1_id, drug2_id), similarity in similarities.items():
    if drug1_id in filtered_df3['DrugBank ID'][:50] and drug2_id in filtered_df3['DrugBank ID'][:50]:
        G.add_edge(drug1_id, drug2_id, similarity=similarity)

# Visualize the graph
pos = nx.spring_layout(G)  # Positions for all nodes
nx.draw(G, pos, with_labels=True, node_size=3000, node_color='skyblue', font_size=10, font_weight='bold')
plt.show()

# %%
G = nx.Graph()
df['SMILES'] = df['SMILES'].astype(str).replace('nan', '')

# Add nodes for drugs (only the first 10 rows)
for idx, row in df.head(1000).iterrows():
    smiles = row['SMILES']
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        G.add_node(row['DrugBank ID'], name=row['Name'], groups=row['Drug Groups'], smiles=smiles, formula=row['Formula'])

# Calculate Morgan fingerprints for drugs (only the first 10 rows)
fingerprints = {}
for idx, row in df.head(1000).iterrows():
    mol = Chem.MolFromSmiles(row['SMILES'])
    if mol:
        fp = AllChem.GetMorganFingerprintAsBitVect(mol, 2)
        fingerprints[row['DrugBank ID']] = fp

# Calculate Tanimoto similarity between drugs (only the first 10 rows)
similarities = {}
for drug1_id, fp1 in fingerprints.items():
    for drug2_id, fp2 in fingerprints.items():
        if drug1_id != drug2_id:
            similarity = DataStructs.TanimotoSimilarity(fp1, fp2)
            if similarity > 0.1:  # Adjust threshold as needed
                if (drug2_id, drug1_id) not in similarities:  # Avoid duplicate edges
                    similarities[(drug1_id, drug2_id)] = similarity

# Add edges to the graph based on similarity (only for the first 10 drugs)
for (drug1_id, drug2_id), similarity in similarities.items():
    if drug1_id in df['DrugBank ID'][:1000] and drug2_id in df['DrugBank ID'][:1000]:
        G.add_edge(drug1_id, drug2_id, similarity=similarity)

# Visualize the graph
pos = nx.spring_layout(G)  # Positions for all nodes
nx.draw(G, pos, with_labels=True, node_size=3000, node_color='skyblue', font_size=10, font_weight='bold')
plt.show()
